# %%
pip install -U transformers accelerate bitsandbytes peft trl datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.2)
# Collecting transformers
#   Downloading transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.48.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.18.0)
# Collecting trl
#   Downloading trl-0.25.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Collecting datasets
#   Downloading datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.9.0+cu126)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 140.5 MB/s eta 0:00:00
# Downloading bitsandbytes-0.48.2-py3-none-manylinux_2_24_x86_64.whl (59.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 43.9 MB/s eta 0:00:00
# Downloading trl-0.25.1-py3-none-any.whl (465 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.5/465.5 kB 33.1 MB/s eta 0:00:00
# Downloading datasets-4.4.1-py3-none-any.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 36.7 MB/s eta 0:00:00
# Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 54.7 MB/s eta 0:00:00
# Installing collected packages: pyarrow, transformers, datasets, bitsandbytes, trl
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.2
#     Uninstalling transformers-4.57.2:
#       Successfully uninstalled transformers-4.57.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed bitsandbytes-0.48.2 datasets-4.4.1 pyarrow-22.0.0 transformers-4.57.3 trl-0.25.1

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
import torch

import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, classification_report

import os, json, csv, re
from pathlib import Path

from collections import Counter
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

os.environ["WANDB_DISABLED"] = "true"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Model = "mistralai/Mistral-7B-Instruct-v0.3"
BASE_DIR = "/content/drive/MyDrive/Colab Notebooks/DataSci_266_NLP/Final_Project"
OUTPUT_DIR = BASE_DIR + "/Drug_Review/mistral_cls_adapter_001"
os.makedirs(OUTPUT_DIR, exist_ok=True)

Train_path = BASE_DIR + "/Drug_Review/train.csv"
Val_path = BASE_DIR + "/Drug_Review/val.csv"
# Test_path = BASE_DIR + "/Drug_Review/test_medical_abstract.csv"

Labels = ["1-2 stars", "3-4 stars", "5-6 stars", "7-8 stars", "9-10 stars"]

# %%
import json
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from tqdm import tqdm
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
from datasets import Dataset

# %%
OFFLOAD_DIR="./offload"
os.makedirs(OFFLOAD_DIR, exist_ok=True)

# %%
# ----------------------------
# CONFIG: Match your training data structure
# ----------------------------
MODEL_CHECKPOINT = OUTPUT_DIR
# ----------------------------
# SETUP
# ----------------------------
device = "cuda" if torch.cuda.is_available() else "cpu"
tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_CHECKPOINT,
    torch_dtype=torch.float16 if device == "cuda" else torch.float32,
    device_map="auto"
)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    pad_token_id=tokenizer.pad_token_id
)
# Out:
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
def build_example(text, label=None):
    system = "You are a helpful classifier. Reply with exactly one label from: " + ", ".join(Labels) + "."
    user = f"Text: {text}\nLabel options: " + ", ".join(Labels) + "\nAnswer with one label only."
    return {
        "system": system,
        "user": user,
    }

def df_to_hf(df, is_train=True): # converts df into a Hugging Face dataset
    recs = []
    for _, row in df.iterrows():
        recs.append(build_example(row["text"], Labels[row["label"]] if is_train else None))
    return Dataset.from_list(recs)

# %%
# Load validation data
val_df = pd.read_csv(Val_path)
val_ds = df_to_hf(val_df)

# %%
val_df.head()
# Out:
#                            drugName                       condition  \
# 0           amoxicillin clavulanate   skin or soft tissue infection
# 1                            gianvi  premenstrual dysphoric disorde
# 2                           liletta                   birth control
# 3  ethinyl estradiol levonorgestrel                   birth control
# 4    ethinyl estradiol norgestimate                   birth control
#
#                                               review  \
# 0  this med was given as a result of a deep gouge...
# 1  i was given this generic by my pharmacy who di...
# 2  i have had the liletta iud in place for about ...
# 3  this is my second month on lutera and it has s...
# 4  sprintec is great for me. i have taken it for ...
#
#                                                 text  label
# 0  amoxicillin clavulanate | skin or soft tissue ...      0
# 1  gianvi | premenstrual dysphoric disorde | i wa...      0
# 2  liletta | birth control | i have had the lilet...      0
# 3  ethinyl estradiol levonorgestrel | birth contr...      2
# 4  ethinyl estradiol norgestimate | birth control...      4

# %%
for ex in val_ds.take(5):
  print(ex)
# Out:
# {'system': 'You are a helpful classifier. Reply with exactly one label from: 1-2 stars, 3-4 stars, 5-6 stars, 7-8 stars, 9-10 stars.', 'user': 'Text: amoxicillin clavulanate | skin or soft tissue infection | this med was given as a result of a deep gouge from a dog nail. healing was not occurring after 4 weeks including a trip to a ambulatory care. my doc said they treated it incorrectly. he prescribed this. i have an appointment at the wound center tues. dr also said it needed debriding. after 5 days i see no improvement. if anything the area is more red and sore.\nLabel options: 1-2 stars, 3-4 stars, 5-6 stars, 7-8 stars, 9-10 stars\nAnswer with one label only.'}
# {'system': 'You are a helpful classifier. Reply with exactly one label from: 1-2 stars, 3-4 stars, 5-6 stars, 7-8 stars, 9-10 stars.', 'user': 'Text: gianvi | premenstrual dysphoric disorde | i was given this generic by my pharmacy who did not inform me that it was a generic that my insurance company told them to give me even though the doctor has specifically prescribed yaz to treat my pmdd symptoms. my main pmdd symptom was menstrual migraines. after about 2 weeks of being on gianvi i was suffering from constant headaches that got progressively worse until my doctor told me to stop taking it. in addition to this side effect i suffered from persistent muscle spasms and extreme changes in appetite.\nLabel options: 1-2 stars, 3-4 stars, 5-6 stars, 7-8 stars, 9-10 stars\nAnswer with one label only.'}
# {'system': 'You are a helpful classifier. Reply with exactly one label from: 1-2 stars, 3-4 stars, 5-6 stars, 7-8 stars, 9-10 stars.', 'user': 'Text: liletta | birth control | i have had the liletta iud in place for about 4 months now. i dont recommend getting this form of birth control. insertion is very painful. i didnt bleed that hard after insertion and have had a period every month but more recently i have been getting horrible random cramps with slight spotting, terrible back pain, headaches, having a terrible time losing the baby weight (shes 7 months old... only lost 8 pounds), worse acne then i had in highschool, fatigued, and extreme mood swings. think 3 times before getting this put in place. i am scheduled to get mine removed in a week and i cant wait.\nLabel options: 1-2 stars, 3-4 stars, 5-6 stars, 7-8 stars, 9-10 stars\nAnswer with one label only.'}
# {'system': 'You are a helpful classifier. Reply with exactly one label from: 1-2 stars, 3-4 stars, 5-6 stars, 7-8 stars, 9-10 stars.', 'user': 'Text: ethinyl estradiol levonorgestrel | birth control | this is my second month on lutera and it has sucked. i just had news that i may have a blood clot in my neck because of the med. it has caused me unbearable migraines and a bit of vision problems. my doctor has just told me to stop because i am very likely to get thrombosis because of this birth control\nLabel options: 1-2 stars, 3-4 stars, 5-6 stars, 7-8 stars, 9-10 stars\nAnswer with one label only.'}
# {'system': 'You are a helpful classifier. Reply with exactly one label from: 1-2 stars, 3-4 stars, 5-6 stars, 7-8 stars, 9-10 stars.', 'user': 'Text: ethinyl estradiol norgestimate | birth control | sprintec is great for me. i have taken it for a year a half (19 years old) never had any problems but i guess that shows it works different for everyone. my breasts got bigger. i didnt gain any weight, periods became shorter, lighter periods and i rarely have cramps if i do they arent bad. before i got on sprintec i had really heavy periods, all 7 days long horrible cramps to the point where i would miss school and work. its affordable and i would recommend sprintec to anyone.\nLabel options: 1-2 stars, 3-4 stars, 5-6 stars, 7-8 stars, 9-10 stars\nAnswer with one label only.'}

# %%
def formatting_func(example):
    messages = [
        {"role": "system", "content": example["system"]},
        {"role": "user", "content": example["user"]},
    ]
    # Convert chat messages to a single text sequence (no tokenization yet)
    return tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

# %%
# ----------------------------------
# OUTPUT PATHS
# ----------------------------------
RUN_NAME = "test_preds"                     # change if you like
OUT_DIR = Path (BASE_DIR + "/Helen/mistral_cls_adapter")
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_JSONL = OUT_DIR / f"{RUN_NAME}.jsonl"  # append-safe
OUT_CSV   = OUT_DIR / f"{RUN_NAME}.csv"    # optional rolling CSV
METRICS_JSONL = OUT_DIR / f"{RUN_NAME}.metrics.jsonl"  # per-batch + cumulative
METRICS_CSV   = OUT_DIR / f"{RUN_NAME}.metrics.csv"    # rolling CSV

# %%
# ----------------------------------
# LABEL PARSER (simple + robust)
# ----------------------------------
LABELS_SET = {lbl.lower(): lbl for lbl in Labels}  # preserve canonical form

def parse_label(text: str, fallback: str = "Unknown"):
    """
    Extract the first label that appears in the generation.
    Matches whole labels case-insensitively; tolerates extra words/punctuation.
    """
    t = text.strip().lower()
    # Exact match first
    if t in LABELS_SET:
        return LABELS_SET[t]
    # Look for any label as a whole word/phrase
    for lbl in Labels:
        pattern = r"\b" + re.escape(lbl.lower()) + r"\b"
        if re.search(pattern, t):
            return lbl
    # Sometimes models return like: "Label: Anxiety/Stress"
    m = re.search(r"label\s*[:\-]\s*(.+)", t)
    if m:
        cand = m.group(1).strip().lower()
        # try direct
        if cand in LABELS_SET:
            return LABELS_SET[cand]
        # try partial up to punctuation/newline
        cand = re.split(r"[\n\r\.,;!?\-]", cand)[0].strip()
        if cand in LABELS_SET:
            return LABELS_SET[cand]
    return fallback

# ----------------------------------
# INCREMENTAL WRITERS
# ----------------------------------
def append_jsonl(path: Path, records):
    with open(path, "a", encoding="utf-8") as f:
        for r in records:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

def append_csv(path: Path, records, fieldnames):
    file_exists = path.exists()
    with open(path, "a", encoding="utf-8", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        if not file_exists:
            writer.writeheader()
        writer.writerows(records)

# If labels are stored in val_ds as 'label' or 'status_combined':
def extract_true_label(ex):
    if "label" in ex and ex["label"] is not None:
        return ex["label"]
    if "status_combined" in ex and ex["status_combined"] is not None:
        return ex["status_combined"]
    # If labels are in a separate DataFrame, align by index and return here:
    # return val_df.loc[ex["row_id"], "status_combined"]
    return None

# %%
# ----------------------------------
# Build prompts + ground-truth labels (aligned!)
# ----------------------------------

# If test_ds is an HF Dataset of dicts with keys 'system' and 'user'
# build all prompts once (keeps order stable)
prompts = [formatting_func(ex) for ex in val_ds]
true_labels = [Labels[extract_true_label(val_df.iloc[i])] for i in range(len(val_df))]

# Sanity: map any stray labels to canonical spellings
canon = {lbl.lower(): lbl for lbl in Labels}
true_labels = [canon.get((t or "").lower(), t) for t in true_labels]

# ----------------------------------
# Batch inference + incremental example saving + metrics
# ----------------------------------
BATCH_SIZE = 32
example_fieldnames = ["index", "system", "user", "generated_text", "pred_label"]
metric_fieldnames = [
    "batch_start", "batch_end", "batch_size",
    "batch_acc", "batch_f1_macro", "batch_f1_weighted",
    "cum_seen", "cum_acc", "cum_f1_macro", "cum_f1_weighted",
    "unknown_preds_in_batch"
]

all_preds = []
all_trues = []

model.eval()
with torch.no_grad():
    for i in range(0, len(prompts), BATCH_SIZE):
        batch_prompts = prompts[i:i+BATCH_SIZE]
        batch_trues = true_labels[i:i+BATCH_SIZE]

        outputs = generator(
            batch_prompts,
            max_new_tokens=50,
            do_sample=False,
            return_full_text=False,
            batch_size=BATCH_SIZE,
            truncation=True
        )

        # Parse predictions
        batch_preds = []
        example_records = []
        unknown_count = 0

        for j, out in enumerate(outputs):
            idx = i + j
            gen_text = out[0]["generated_text"]
            pred = parse_label(gen_text)
            if pred not in Labels:
                unknown_count += 1
            ex = val_ds[idx]  # contains system/user used to build the prompt

            example_records.append({
                "index": idx,
                "system": ex["system"],
                "user": ex["user"],
                "generated_text": gen_text,
                "pred_label": pred
            })
            batch_preds.append(pred)

        # Save examples incrementally
        append_jsonl(OUT_JSONL, example_records)
        append_csv(OUT_CSV, example_records, example_fieldnames)

        # -------------------------
        # Compute per-batch metrics
        # -------------------------
        # Filter out None ground-truths if present
        mask = [t is not None for t in batch_trues]
        bt_trues = [t for t, m in zip(batch_trues, mask) if m]
        bt_preds = [p for p, m in zip(batch_preds, mask) if m]

        if len(bt_trues) > 0:
            # Any 'Unknown' predictions are treated as-is (will count as wrong)
            batch_acc = accuracy_score(bt_trues, bt_preds)
            batch_f1_macro = f1_score(bt_trues, bt_preds, labels=Labels, average="macro", zero_division=0)
            batch_f1_weighted = f1_score(bt_trues, bt_preds, labels=Labels, average="weighted", zero_division=0)
        else:
            batch_acc = batch_f1_macro = batch_f1_weighted = float("nan")

        # Update cumulative
        all_trues.extend(bt_trues)
        all_preds.extend(bt_preds)

        if len(all_trues) > 0:
            cum_acc = accuracy_score(all_trues, all_preds)
            cum_f1_macro = f1_score(all_trues, all_preds, labels=Labels, average="macro", zero_division=0)
            cum_f1_weighted = f1_score(all_trues, all_preds, labels=Labels, average="weighted", zero_division=0)
        else:
            cum_acc = cum_f1_macro = cum_f1_weighted = float("nan")

        # Save metrics incrementally
        metric_row = {
            "batch_start": i,
            "batch_end": i + len(batch_prompts) - 1,
            "batch_size": len(bt_trues),
            "batch_acc": round(batch_acc, 4) if batch_acc == batch_acc else None,
            "batch_f1_macro": round(batch_f1_macro, 4) if batch_f1_macro == batch_f1_macro else None,
            "batch_f1_weighted": round(batch_f1_weighted, 4) if batch_f1_weighted == batch_f1_weighted else None,
            "cum_seen": len(all_trues),
            "cum_acc": round(cum_acc, 4) if cum_acc == cum_acc else None,
            "cum_f1_macro": round(cum_f1_macro, 4) if cum_f1_macro == cum_f1_macro else None,
            "cum_f1_weighted": round(cum_f1_weighted, 4) if cum_f1_weighted == cum_f1_weighted else None,
            "unknown_preds_in_batch": unknown_count,
        }
        append_jsonl(METRICS_JSONL, [metric_row])
        append_csv(METRICS_CSV, [metric_row], metric_fieldnames)

        # Console display (compact)
        print(
            f"[{i:>5d}-{i+len(batch_prompts)-1:<5d}] "
            f"batch_acc={metric_row['batch_acc']} | "
            f"batch_f1(macro)={metric_row['batch_f1_macro']} | "
            f"cum_acc={metric_row['cum_acc']} | "
            f"cum_f1(macro)={metric_row['cum_f1_macro']} | "
            f"unknown={unknown_count}"
        )

# Optional: final detailed report + confusion matrix
if len(all_trues) > 0:
    print("\nFinal classification report (cumulative):")
    print(classification_report(all_trues, all_preds, labels=Labels, digits=4, zero_division=0))
    print("Confusion matrix (rows=true, cols=pred):")
    print(confusion_matrix(all_trues, all_preds, labels=Labels))
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [    0-31   ] batch_acc=0.8438 | batch_f1(macro)=0.5504 | cum_acc=0.8438 | cum_f1(macro)=0.5504 | unknown=0
# [   32-63   ] batch_acc=0.6875 | batch_f1(macro)=0.6509 | cum_acc=0.7656 | cum_f1(macro)=0.6264 | unknown=0
# [   64-95   ] batch_acc=0.5938 | batch_f1(macro)=0.4448 | cum_acc=0.7083 | cum_f1(macro)=0.5639 | unknown=0
# [   96-127  ] batch_acc=0.8125 | batch_f1(macro)=0.5973 | cum_acc=0.7344 | cum_f1(macro)=0.5844 | unknown=0
# [  128-159  ] batch_acc=0.7188 | batch_f1(macro)=0.6698 | cum_acc=0.7312 | cum_f1(macro)=0.6113 | unknown=0
# [  160-191  ] batch_acc=0.625 | batch_f1(macro)=0.4428 | cum_acc=0.7135 | cum_f1(macro)=0.5949 | unknown=0
# [  192-223  ] batch_acc=0.5938 | batch_f1(macro)=0.483 | cum_acc=0.6964 | cum_f1(macro)=0.5748 | unknown=0
# [  224-255  ] batch_acc=0.6875 | batch_f1(macro)=0.4831 | cum_acc=0.6953 | cum_f1(macro)=0.5699 | unknown=0
# [  256-287  ] batch_acc=0.625 | batch_f1(macro)=0.5424 | cum_acc=0.6875 | cum_f1(macro)=0.5664 | unknown=0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# [  288-319  ] batch_acc=0.7812 | batch_f1(macro)=0.6869 | cum_acc=0.6969 | cum_f1(macro)=0.5793 | unknown=0
# [  320-351  ] batch_acc=0.6875 | batch_f1(macro)=0.4944 | cum_acc=0.696 | cum_f1(macro)=0.5802 | unknown=0
# [  352-383  ] batch_acc=0.8438 | batch_f1(macro)=0.7616 | cum_acc=0.7083 | cum_f1(macro)=0.5913 | unknown=0
# [  384-415  ] batch_acc=0.7188 | batch_f1(macro)=0.4416 | cum_acc=0.7091 | cum_f1(macro)=0.5858 | unknown=0
# [  416-447  ] batch_acc=0.7812 | batch_f1(macro)=0.6354 | cum_acc=0.7143 | cum_f1(macro)=0.5885 | unknown=0
# [  448-479  ] batch_acc=0.7812 | batch_f1(macro)=0.5761 | cum_acc=0.7188 | cum_f1(macro)=0.5923 | unknown=0
# [  480-511  ] batch_acc=0.7188 | batch_f1(macro)=0.5664 | cum_acc=0.7188 | cum_f1(macro)=0.5969 | unknown=0
# [  512-543  ] batch_acc=0.75 | batch_f1(macro)=0.5583 | cum_acc=0.7206 | cum_f1(macro)=0.5965 | unknown=0
# [  544-575  ] batch_acc=0.6562 | batch_f1(macro)=0.3902 | cum_acc=0.717 | cum_f1(macro)=0.5885 | unknown=0
# [  576-607  ] batch_acc=0.6875 | batch_f1(macro)=0.6778 | cum_acc=0.7155 | cum_f1(macro)=0.5936 | unknown=0
# [  608-639  ] batch_acc=0.7188 | batch_f1(macro)=0.4801 | cum_acc=0.7156 | cum_f1(macro)=0.592 | unknown=0
# [  640-671  ] batch_acc=0.6875 | batch_f1(macro)=0.5715 | cum_acc=0.7143 | cum_f1(macro)=0.5922 | unknown=0
# [  672-703  ] batch_acc=0.8438 | batch_f1(macro)=0.7316 | cum_acc=0.7202 | cum_f1(macro)=0.5977 | unknown=0
# [  704-735  ] batch_acc=0.5625 | batch_f1(macro)=0.3394 | cum_acc=0.7133 | cum_f1(macro)=0.5875 | unknown=0
# [  736-767  ] batch_acc=0.75 | batch_f1(macro)=0.5557 | cum_acc=0.7148 | cum_f1(macro)=0.5865 | unknown=0
# [  768-799  ] batch_acc=0.75 | batch_f1(macro)=0.6416 | cum_acc=0.7163 | cum_f1(macro)=0.589 | unknown=0
# [  800-831  ] batch_acc=0.7812 | batch_f1(macro)=0.5179 | cum_acc=0.7188 | cum_f1(macro)=0.5889 | unknown=0
# [  832-863  ] batch_acc=0.5312 | batch_f1(macro)=0.4482 | cum_acc=0.7118 | cum_f1(macro)=0.5824 | unknown=0
# [  864-895  ] batch_acc=0.7188 | batch_f1(macro)=0.4205 | cum_acc=0.7121 | cum_f1(macro)=0.5789 | unknown=0
# [  896-927  ] batch_acc=0.6562 | batch_f1(macro)=0.4647 | cum_acc=0.7101 | cum_f1(macro)=0.5768 | unknown=0
# [  928-959  ] batch_acc=0.8125 | batch_f1(macro)=0.5958 | cum_acc=0.7135 | cum_f1(macro)=0.5795 | unknown=0
# [  960-991  ] batch_acc=0.6562 | batch_f1(macro)=0.4781 | cum_acc=0.7117 | cum_f1(macro)=0.5769 | unknown=0
# [  992-1023 ] batch_acc=0.75 | batch_f1(macro)=0.4648 | cum_acc=0.7129 | cum_f1(macro)=0.5761 | unknown=0
# [ 1024-1055 ] batch_acc=0.75 | batch_f1(macro)=0.523 | cum_acc=0.714 | cum_f1(macro)=0.5765 | unknown=0
# [ 1056-1087 ] batch_acc=0.6562 | batch_f1(macro)=0.3463 | cum_acc=0.7123 | cum_f1(macro)=0.5714 | unknown=0
# [ 1088-1119 ] batch_acc=0.75 | batch_f1(macro)=0.7501 | cum_acc=0.7134 | cum_f1(macro)=0.5766 | unknown=0
# [ 1120-1151 ] batch_acc=0.5312 | batch_f1(macro)=0.4295 | cum_acc=0.7083 | cum_f1(macro)=0.5723 | unknown=0
# [ 1152-1183 ] batch_acc=0.625 | batch_f1(macro)=0.5143 | cum_acc=0.7061 | cum_f1(macro)=0.5714 | unknown=0
# [ 1184-1215 ] batch_acc=0.6875 | batch_f1(macro)=0.4727 | cum_acc=0.7056 | cum_f1(macro)=0.5685 | unknown=0
# [ 1216-1247 ] batch_acc=0.5938 | batch_f1(macro)=0.2933 | cum_acc=0.7027 | cum_f1(macro)=0.5631 | unknown=0
# [ 1248-1279 ] batch_acc=0.7188 | batch_f1(macro)=0.5662 | cum_acc=0.7031 | cum_f1(macro)=0.5656 | unknown=0
# [ 1280-1311 ] batch_acc=0.625 | batch_f1(macro)=0.5131 | cum_acc=0.7012 | cum_f1(macro)=0.5661 | unknown=0
# [ 1312-1343 ] batch_acc=0.7188 | batch_f1(macro)=0.5476 | cum_acc=0.7016 | cum_f1(macro)=0.5658 | unknown=0
# [ 1344-1375 ] batch_acc=0.6875 | batch_f1(macro)=0.474 | cum_acc=0.7013 | cum_f1(macro)=0.5647 | unknown=0
# [ 1376-1407 ] batch_acc=0.6562 | batch_f1(macro)=0.4318 | cum_acc=0.7003 | cum_f1(macro)=0.5617 | unknown=0
# [ 1408-1439 ] batch_acc=0.7188 | batch_f1(macro)=0.4711 | cum_acc=0.7007 | cum_f1(macro)=0.5606 | unknown=0
# [ 1440-1471 ] batch_acc=0.8125 | batch_f1(macro)=0.6138 | cum_acc=0.7031 | cum_f1(macro)=0.564 | unknown=0
# [ 1472-1503 ] batch_acc=0.7188 | batch_f1(macro)=0.4671 | cum_acc=0.7035 | cum_f1(macro)=0.562 | unknown=0
# [ 1504-1535 ] batch_acc=0.9062 | batch_f1(macro)=0.6305 | cum_acc=0.7077 | cum_f1(macro)=0.5647 | unknown=0
# [ 1536-1567 ] batch_acc=0.6562 | batch_f1(macro)=0.5635 | cum_acc=0.7066 | cum_f1(macro)=0.5649 | unknown=0
# [ 1568-1599 ] batch_acc=0.5312 | batch_f1(macro)=0.3673 | cum_acc=0.7031 | cum_f1(macro)=0.561 | unknown=0
# [ 1600-1631 ] batch_acc=0.7188 | batch_f1(macro)=0.5394 | cum_acc=0.7034 | cum_f1(macro)=0.5609 | unknown=0
# [ 1632-1663 ] batch_acc=0.8125 | batch_f1(macro)=0.6094 | cum_acc=0.7055 | cum_f1(macro)=0.5636 | unknown=0
# [ 1664-1695 ] batch_acc=0.6562 | batch_f1(macro)=0.4178 | cum_acc=0.7046 | cum_f1(macro)=0.5625 | unknown=0
# [ 1696-1727 ] batch_acc=0.7188 | batch_f1(macro)=0.4983 | cum_acc=0.7049 | cum_f1(macro)=0.5621 | unknown=0
# [ 1728-1759 ] batch_acc=0.625 | batch_f1(macro)=0.4821 | cum_acc=0.7034 | cum_f1(macro)=0.5606 | unknown=0
# [ 1760-1791 ] batch_acc=0.75 | batch_f1(macro)=0.4855 | cum_acc=0.7042 | cum_f1(macro)=0.5594 | unknown=0
# [ 1792-1823 ] batch_acc=0.8125 | batch_f1(macro)=0.6181 | cum_acc=0.7061 | cum_f1(macro)=0.5614 | unknown=0
# [ 1824-1855 ] batch_acc=0.7188 | batch_f1(macro)=0.5029 | cum_acc=0.7064 | cum_f1(macro)=0.5606 | unknown=0
# [ 1856-1887 ] batch_acc=0.7812 | batch_f1(macro)=0.6698 | cum_acc=0.7076 | cum_f1(macro)=0.5624 | unknown=0
# [ 1888-1919 ] batch_acc=0.7812 | batch_f1(macro)=0.5377 | cum_acc=0.7089 | cum_f1(macro)=0.5631 | unknown=0
# [ 1920-1951 ] batch_acc=0.8125 | batch_f1(macro)=0.4829 | cum_acc=0.7106 | cum_f1(macro)=0.5635 | unknown=0
# [ 1952-1983 ] batch_acc=0.9062 | batch_f1(macro)=0.6708 | cum_acc=0.7137 | cum_f1(macro)=0.5667 | unknown=0
# [ 1984-2015 ] batch_acc=0.6562 | batch_f1(macro)=0.6758 | cum_acc=0.7128 | cum_f1(macro)=0.5678 | unknown=0
# [ 2016-2047 ] batch_acc=0.7188 | batch_f1(macro)=0.6024 | cum_acc=0.7129 | cum_f1(macro)=0.5689 | unknown=0
# [ 2048-2079 ] batch_acc=0.7188 | batch_f1(macro)=0.5364 | cum_acc=0.713 | cum_f1(macro)=0.5687 | unknown=0
# [ 2080-2111 ] batch_acc=0.6562 | batch_f1(macro)=0.4881 | cum_acc=0.7121 | cum_f1(macro)=0.5678 | unknown=0
# [ 2112-2143 ] batch_acc=0.75 | batch_f1(macro)=0.6656 | cum_acc=0.7127 | cum_f1(macro)=0.5698 | unknown=0
# [ 2144-2175 ] batch_acc=0.5 | batch_f1(macro)=0.3455 | cum_acc=0.7096 | cum_f1(macro)=0.5667 | unknown=0
# [ 2176-2207 ] batch_acc=0.875 | batch_f1(macro)=0.7817 | cum_acc=0.712 | cum_f1(macro)=0.57 | unknown=0
# [ 2208-2239 ] batch_acc=0.8438 | batch_f1(macro)=0.4576 | cum_acc=0.7138 | cum_f1(macro)=0.5701 | unknown=0
# [ 2240-2271 ] batch_acc=0.75 | batch_f1(macro)=0.6994 | cum_acc=0.7143 | cum_f1(macro)=0.5723 | unknown=0
# [ 2272-2303 ] batch_acc=0.6562 | batch_f1(macro)=0.5149 | cum_acc=0.7135 | cum_f1(macro)=0.5713 | unknown=0
# [ 2304-2335 ] batch_acc=0.6875 | batch_f1(macro)=0.5741 | cum_acc=0.7132 | cum_f1(macro)=0.5716 | unknown=0
# [ 2336-2367 ] batch_acc=0.7188 | batch_f1(macro)=0.5362 | cum_acc=0.7133 | cum_f1(macro)=0.5708 | unknown=0
# [ 2368-2399 ] batch_acc=0.7188 | batch_f1(macro)=0.6405 | cum_acc=0.7133 | cum_f1(macro)=0.5722 | unknown=0
# [ 2400-2431 ] batch_acc=0.7188 | batch_f1(macro)=0.6269 | cum_acc=0.7134 | cum_f1(macro)=0.5731 | unknown=0
# [ 2432-2463 ] batch_acc=0.6562 | batch_f1(macro)=0.4281 | cum_acc=0.7127 | cum_f1(macro)=0.5721 | unknown=0
# [ 2464-2495 ] batch_acc=0.75 | batch_f1(macro)=0.7159 | cum_acc=0.7131 | cum_f1(macro)=0.5738 | unknown=0
# [ 2496-2527 ] batch_acc=0.625 | batch_f1(macro)=0.4683 | cum_acc=0.712 | cum_f1(macro)=0.5732 | unknown=0
# [ 2528-2559 ] batch_acc=0.6875 | batch_f1(macro)=0.4584 | cum_acc=0.7117 | cum_f1(macro)=0.5739 | unknown=0
# [ 2560-2591 ] batch_acc=0.6562 | batch_f1(macro)=0.5218 | cum_acc=0.711 | cum_f1(macro)=0.5732 | unknown=0
# [ 2592-2623 ] batch_acc=0.6562 | batch_f1(macro)=0.472 | cum_acc=0.7104 | cum_f1(macro)=0.5722 | unknown=0
# [ 2624-2655 ] batch_acc=0.7188 | batch_f1(macro)=0.438 | cum_acc=0.7105 | cum_f1(macro)=0.5719 | unknown=0
# [ 2656-2687 ] batch_acc=0.75 | batch_f1(macro)=0.5472 | cum_acc=0.7109 | cum_f1(macro)=0.5722 | unknown=0
# [ 2688-2719 ] batch_acc=0.5625 | batch_f1(macro)=0.4227 | cum_acc=0.7092 | cum_f1(macro)=0.5702 | unknown=0
# [ 2720-2751 ] batch_acc=0.8438 | batch_f1(macro)=0.7448 | cum_acc=0.7108 | cum_f1(macro)=0.572 | unknown=0
# [ 2752-2783 ] batch_acc=0.6875 | batch_f1(macro)=0.3833 | cum_acc=0.7105 | cum_f1(macro)=0.5716 | unknown=0
# [ 2784-2815 ] batch_acc=0.8125 | batch_f1(macro)=0.5471 | cum_acc=0.7116 | cum_f1(macro)=0.5721 | unknown=0
# [ 2816-2847 ] batch_acc=0.625 | batch_f1(macro)=0.4636 | cum_acc=0.7107 | cum_f1(macro)=0.5704 | unknown=0
# [ 2848-2879 ] batch_acc=0.7188 | batch_f1(macro)=0.6289 | cum_acc=0.7108 | cum_f1(macro)=0.571 | unknown=0
# [ 2880-2911 ] batch_acc=0.6562 | batch_f1(macro)=0.4819 | cum_acc=0.7102 | cum_f1(macro)=0.57 | unknown=0
# [ 2912-2943 ] batch_acc=0.75 | batch_f1(macro)=0.4772 | cum_acc=0.7106 | cum_f1(macro)=0.5695 | unknown=0
# [ 2944-2975 ] batch_acc=0.5938 | batch_f1(macro)=0.5095 | cum_acc=0.7093 | cum_f1(macro)=0.569 | unknown=0
# [ 2976-3007 ] batch_acc=0.75 | batch_f1(macro)=0.582 | cum_acc=0.7098 | cum_f1(macro)=0.5693 | unknown=0
# [ 3008-3039 ] batch_acc=0.75 | batch_f1(macro)=0.5355 | cum_acc=0.7102 | cum_f1(macro)=0.5694 | unknown=0
# [ 3040-3071 ] batch_acc=0.75 | batch_f1(macro)=0.6264 | cum_acc=0.7106 | cum_f1(macro)=0.5701 | unknown=0
# [ 3072-3103 ] batch_acc=0.6562 | batch_f1(macro)=0.4533 | cum_acc=0.7101 | cum_f1(macro)=0.5694 | unknown=0
# [ 3104-3135 ] batch_acc=0.6562 | batch_f1(macro)=0.4971 | cum_acc=0.7095 | cum_f1(macro)=0.5695 | unknown=0
# [ 3136-3167 ] batch_acc=0.8125 | batch_f1(macro)=0.4244 | cum_acc=0.7105 | cum_f1(macro)=0.5696 | unknown=0
# [ 3168-3199 ] batch_acc=0.625 | batch_f1(macro)=0.4739 | cum_acc=0.7097 | cum_f1(macro)=0.5689 | unknown=0
# [ 3200-3231 ] batch_acc=0.6562 | batch_f1(macro)=0.5071 | cum_acc=0.7092 | cum_f1(macro)=0.5684 | unknown=0
# [ 3232-3263 ] batch_acc=0.75 | batch_f1(macro)=0.6061 | cum_acc=0.7096 | cum_f1(macro)=0.569 | unknown=0
# [ 3264-3295 ] batch_acc=0.75 | batch_f1(macro)=0.663 | cum_acc=0.71 | cum_f1(macro)=0.5703 | unknown=0
# [ 3296-3327 ] batch_acc=0.625 | batch_f1(macro)=0.5944 | cum_acc=0.7091 | cum_f1(macro)=0.571 | unknown=0
# [ 3328-3359 ] batch_acc=0.7188 | batch_f1(macro)=0.5056 | cum_acc=0.7092 | cum_f1(macro)=0.5708 | unknown=0
# [ 3360-3391 ] batch_acc=0.7812 | batch_f1(macro)=0.4829 | cum_acc=0.7099 | cum_f1(macro)=0.5707 | unknown=0
# [ 3392-3423 ] batch_acc=0.7188 | batch_f1(macro)=0.557 | cum_acc=0.71 | cum_f1(macro)=0.5708 | unknown=0
# [ 3424-3455 ] batch_acc=0.8438 | batch_f1(macro)=0.5352 | cum_acc=0.7112 | cum_f1(macro)=0.5714 | unknown=0
# [ 3456-3487 ] batch_acc=0.8438 | batch_f1(macro)=0.8263 | cum_acc=0.7124 | cum_f1(macro)=0.5729 | unknown=0
# [ 3488-3519 ] batch_acc=0.6875 | batch_f1(macro)=0.5972 | cum_acc=0.7122 | cum_f1(macro)=0.5731 | unknown=0
# [ 3520-3551 ] batch_acc=0.7812 | batch_f1(macro)=0.5447 | cum_acc=0.7128 | cum_f1(macro)=0.573 | unknown=0
# [ 3552-3583 ] batch_acc=0.625 | batch_f1(macro)=0.4721 | cum_acc=0.7121 | cum_f1(macro)=0.5719 | unknown=0
# [ 3584-3615 ] batch_acc=0.7188 | batch_f1(macro)=0.4518 | cum_acc=0.7121 | cum_f1(macro)=0.5717 | unknown=0
# [ 3616-3647 ] batch_acc=0.75 | batch_f1(macro)=0.6031 | cum_acc=0.7124 | cum_f1(macro)=0.5724 | unknown=0
# [ 3648-3679 ] batch_acc=0.5 | batch_f1(macro)=0.3706 | cum_acc=0.7106 | cum_f1(macro)=0.5708 | unknown=0
# [ 3680-3711 ] batch_acc=0.75 | batch_f1(macro)=0.6219 | cum_acc=0.7109 | cum_f1(macro)=0.5712 | unknown=0
# [ 3712-3743 ] batch_acc=0.75 | batch_f1(macro)=0.4565 | cum_acc=0.7113 | cum_f1(macro)=0.5708 | unknown=0
# [ 3744-3775 ] batch_acc=0.8438 | batch_f1(macro)=0.7824 | cum_acc=0.7124 | cum_f1(macro)=0.5719 | unknown=0
# [ 3776-3807 ] batch_acc=0.6562 | batch_f1(macro)=0.4677 | cum_acc=0.7119 | cum_f1(macro)=0.5711 | unknown=0
# [ 3808-3839 ] batch_acc=0.7812 | batch_f1(macro)=0.6216 | cum_acc=0.7125 | cum_f1(macro)=0.5721 | unknown=0
# [ 3840-3871 ] batch_acc=0.5625 | batch_f1(macro)=0.3593 | cum_acc=0.7113 | cum_f1(macro)=0.5711 | unknown=0
# [ 3872-3903 ] batch_acc=0.8438 | batch_f1(macro)=0.62 | cum_acc=0.7123 | cum_f1(macro)=0.5719 | unknown=0
# [ 3904-3935 ] batch_acc=0.875 | batch_f1(macro)=0.6651 | cum_acc=0.7137 | cum_f1(macro)=0.5731 | unknown=0
# [ 3936-3967 ] batch_acc=0.75 | batch_f1(macro)=0.6851 | cum_acc=0.714 | cum_f1(macro)=0.5741 | unknown=0
# [ 3968-3999 ] batch_acc=0.625 | batch_f1(macro)=0.474 | cum_acc=0.7133 | cum_f1(macro)=0.5734 | unknown=0
# [ 4000-4031 ] batch_acc=0.875 | batch_f1(macro)=0.7452 | cum_acc=0.7145 | cum_f1(macro)=0.5746 | unknown=0
# [ 4032-4063 ] batch_acc=0.9375 | batch_f1(macro)=0.5571 | cum_acc=0.7163 | cum_f1(macro)=0.5756 | unknown=0
# [ 4064-4095 ] batch_acc=0.6875 | batch_f1(macro)=0.4975 | cum_acc=0.7161 | cum_f1(macro)=0.5753 | unknown=0
# [ 4096-4127 ] batch_acc=0.875 | batch_f1(macro)=0.7647 | cum_acc=0.7173 | cum_f1(macro)=0.5764 | unknown=0
# [ 4128-4159 ] batch_acc=0.5625 | batch_f1(macro)=0.4434 | cum_acc=0.7161 | cum_f1(macro)=0.5753 | unknown=0
# [ 4160-4191 ] batch_acc=0.6875 | batch_f1(macro)=0.3687 | cum_acc=0.7159 | cum_f1(macro)=0.5742 | unknown=0
# [ 4192-4223 ] batch_acc=0.6875 | batch_f1(macro)=0.5181 | cum_acc=0.7157 | cum_f1(macro)=0.5738 | unknown=0
# [ 4224-4255 ] batch_acc=0.75 | batch_f1(macro)=0.663 | cum_acc=0.7159 | cum_f1(macro)=0.5744 | unknown=0
# [ 4256-4287 ] batch_acc=0.8438 | batch_f1(macro)=0.8125 | cum_acc=0.7169 | cum_f1(macro)=0.5773 | unknown=0
# [ 4288-4319 ] batch_acc=0.75 | batch_f1(macro)=0.5243 | cum_acc=0.7171 | cum_f1(macro)=0.5771 | unknown=0
# [ 4320-4351 ] batch_acc=0.7812 | batch_f1(macro)=0.6444 | cum_acc=0.7176 | cum_f1(macro)=0.5777 | unknown=0
# [ 4352-4383 ] batch_acc=0.75 | batch_f1(macro)=0.5744 | cum_acc=0.7178 | cum_f1(macro)=0.5778 | unknown=0
# [ 4384-4415 ] batch_acc=0.625 | batch_f1(macro)=0.3036 | cum_acc=0.7172 | cum_f1(macro)=0.5767 | unknown=0
# [ 4416-4447 ] batch_acc=0.5938 | batch_f1(macro)=0.4438 | cum_acc=0.7163 | cum_f1(macro)=0.576 | unknown=0
# [ 4448-4479 ] batch_acc=0.7812 | batch_f1(macro)=0.4921 | cum_acc=0.7167 | cum_f1(macro)=0.576 | unknown=0
# [ 4480-4511 ] batch_acc=0.7188 | batch_f1(macro)=0.5206 | cum_acc=0.7168 | cum_f1(macro)=0.576 | unknown=0
# [ 4512-4543 ] batch_acc=0.7812 | batch_f1(macro)=0.5733 | cum_acc=0.7172 | cum_f1(macro)=0.5759 | unknown=0
# [ 4544-4575 ] batch_acc=0.75 | batch_f1(macro)=0.6676 | cum_acc=0.7174 | cum_f1(macro)=0.5767 | unknown=0
# [ 4576-4607 ] batch_acc=0.8125 | batch_f1(macro)=0.8159 | cum_acc=0.7181 | cum_f1(macro)=0.5779 | unknown=0
# [ 4608-4639 ] batch_acc=0.7812 | batch_f1(macro)=0.4848 | cum_acc=0.7185 | cum_f1(macro)=0.5783 | unknown=0
# [ 4640-4671 ] batch_acc=0.6875 | batch_f1(macro)=0.4145 | cum_acc=0.7183 | cum_f1(macro)=0.5773 | unknown=0
# [ 4672-4703 ] batch_acc=0.8438 | batch_f1(macro)=0.6147 | cum_acc=0.7192 | cum_f1(macro)=0.578 | unknown=0
# [ 4704-4735 ] batch_acc=0.75 | batch_f1(macro)=0.4314 | cum_acc=0.7194 | cum_f1(macro)=0.5774 | unknown=0
# [ 4736-4767 ] batch_acc=0.75 | batch_f1(macro)=0.5995 | cum_acc=0.7196 | cum_f1(macro)=0.5776 | unknown=0
# [ 4768-4799 ] batch_acc=0.625 | batch_f1(macro)=0.5122 | cum_acc=0.719 | cum_f1(macro)=0.577 | unknown=0
# [ 4800-4831 ] batch_acc=0.6562 | batch_f1(macro)=0.5943 | cum_acc=0.7185 | cum_f1(macro)=0.5774 | unknown=0
# [ 4832-4863 ] batch_acc=0.6875 | batch_f1(macro)=0.525 | cum_acc=0.7183 | cum_f1(macro)=0.5772 | unknown=0
# [ 4864-4895 ] batch_acc=0.8125 | batch_f1(macro)=0.5267 | cum_acc=0.719 | cum_f1(macro)=0.5777 | unknown=0
# [ 4896-4927 ] batch_acc=0.6562 | batch_f1(macro)=0.4267 | cum_acc=0.7185 | cum_f1(macro)=0.5768 | unknown=0
# [ 4928-4959 ] batch_acc=0.8125 | batch_f1(macro)=0.7137 | cum_acc=0.7192 | cum_f1(macro)=0.5779 | unknown=0
# [ 4960-4991 ] batch_acc=0.6875 | batch_f1(macro)=0.5118 | cum_acc=0.719 | cum_f1(macro)=0.5776 | unknown=0
# [ 4992-5023 ] batch_acc=0.7188 | batch_f1(macro)=0.6349 | cum_acc=0.7189 | cum_f1(macro)=0.578 | unknown=0
# [ 5024-5055 ] batch_acc=0.75 | batch_f1(macro)=0.5671 | cum_acc=0.7191 | cum_f1(macro)=0.5781 | unknown=0
# [ 5056-5087 ] batch_acc=0.6875 | batch_f1(macro)=0.4332 | cum_acc=0.7189 | cum_f1(macro)=0.5776 | unknown=0
# [ 5088-5119 ] batch_acc=0.5938 | batch_f1(macro)=0.471 | cum_acc=0.7182 | cum_f1(macro)=0.5771 | unknown=0
# [ 5120-5151 ] batch_acc=0.5625 | batch_f1(macro)=0.44 | cum_acc=0.7172 | cum_f1(macro)=0.5765 | unknown=0
# [ 5152-5183 ] batch_acc=0.7188 | batch_f1(macro)=0.4516 | cum_acc=0.7172 | cum_f1(macro)=0.5758 | unknown=0
# [ 5184-5215 ] batch_acc=0.6562 | batch_f1(macro)=0.5284 | cum_acc=0.7168 | cum_f1(macro)=0.5757 | unknown=0
# [ 5216-5247 ] batch_acc=0.7188 | batch_f1(macro)=0.5213 | cum_acc=0.7168 | cum_f1(macro)=0.5754 | unknown=0
# [ 5248-5279 ] batch_acc=0.6875 | batch_f1(macro)=0.5291 | cum_acc=0.7167 | cum_f1(macro)=0.5748 | unknown=0
# [ 5280-5311 ] batch_acc=0.6875 | batch_f1(macro)=0.6183 | cum_acc=0.7165 | cum_f1(macro)=0.5752 | unknown=0
# [ 5312-5343 ] batch_acc=0.8438 | batch_f1(macro)=0.4626 | cum_acc=0.7173 | cum_f1(macro)=0.5752 | unknown=0
# [ 5344-5375 ] batch_acc=0.5625 | batch_f1(macro)=0.501 | cum_acc=0.7163 | cum_f1(macro)=0.5748 | unknown=0
# [ 5376-5407 ] batch_acc=0.7188 | batch_f1(macro)=0.4349 | cum_acc=0.7163 | cum_f1(macro)=0.5743 | unknown=0
# [ 5408-5439 ] batch_acc=0.6875 | batch_f1(macro)=0.3886 | cum_acc=0.7162 | cum_f1(macro)=0.5736 | unknown=0
# [ 5440-5471 ] batch_acc=0.7812 | batch_f1(macro)=0.6656 | cum_acc=0.7166 | cum_f1(macro)=0.5739 | unknown=0
# [ 5472-5503 ] batch_acc=0.6562 | batch_f1(macro)=0.4427 | cum_acc=0.7162 | cum_f1(macro)=0.5737 | unknown=0
# [ 5504-5535 ] batch_acc=0.75 | batch_f1(macro)=0.4894 | cum_acc=0.7164 | cum_f1(macro)=0.5737 | unknown=0
# [ 5536-5540 ] batch_acc=0.8 | batch_f1(macro)=0.3048 | cum_acc=0.7165 | cum_f1(macro)=0.5737 | unknown=0
#
# Final classification report (cumulative):
#               precision    recall  f1-score   support
#
#    1-2 stars     0.7431    0.8553    0.7953       940
#    3-4 stars     0.3661    0.2641    0.3068       409
#    5-6 stars     0.4248    0.3671    0.3938       523
#    7-8 stars     0.5496    0.4645    0.5035      1014
#   9-10 stars     0.8389    0.9021    0.8693      2655
#
#     accuracy                         0.7165      5541
#    macro avg     0.5845    0.5706    0.5737      5541
# weighted avg     0.6957    0.7165    0.7034      5541
#
# Confusion matrix (rows=true, cols=pred):
# [[ 804   69   51    5   11]
#  [ 174  108   85   35    7]
#  [  74   88  192  129   40]
#  [  20   26   95  471  402]
#  [  10    4   29  217 2395]]

# %%
pred_df = pd.read_csv(OUT_CSV)

# %%
pred_df
# Out:
#       index                                             system  \
# 0         0  You are a helpful classifier. Reply with exact...
# 1         1  You are a helpful classifier. Reply with exact...
# 2         2  You are a helpful classifier. Reply with exact...
# 3         3  You are a helpful classifier. Reply with exact...
# 4         4  You are a helpful classifier. Reply with exact...
# ...     ...                                                ...
# 5536   5536  You are a helpful classifier. Reply with exact...
# 5537   5537  You are a helpful classifier. Reply with exact...
# 5538   5538  You are a helpful classifier. Reply with exact...
# 5539   5539  You are a helpful classifier. Reply with exact...
# 5540   5540  You are a helpful classifier. Reply with exact...
#
#                                                    user generated_text  \
# 0     Text: amoxicillin clavulanate | skin or soft t...      1-2 stars
# 1     Text: gianvi | premenstrual dysphoric disorde ...      1-2 stars
# 2     Text: liletta | birth control | i have had the...      1-2 stars
# 3     Text: ethinyl estradiol levonorgestrel | birth...      1-2 stars
# 4     Text: ethinyl estradiol norgestimate | birth c...     9-10 stars
# ...                                                 ...            ...
# 5536  Text: mirena | abnormal uterine bleeding | wel...     9-10 stars
# 5537  Text: drospirenone ethinyl estradiol | birth c...      7-8 stars
# 5538  Text: liraglutide | diabetes, type 2 | so far ...     9-10 stars
# 5539  Text: ethinyl estradiol norgestimate | birth c...     9-10 stars
# 5540  Text: fiorinal | migraine | ive had chronic mi...     9-10 stars
#
#       pred_label
# 0      1-2 stars
# 1      1-2 stars
# 2      1-2 stars
# 3      1-2 stars
# 4     9-10 stars
# ...          ...
# 5536  9-10 stars
# 5537   7-8 stars
# 5538  9-10 stars
# 5539  9-10 stars
# 5540  9-10 stars
#
# [5541 rows x 5 columns]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Example data
# all_trues = [...]
# all_preds = [...]
# Labels = [...]

# Compute confusion matrix
conf_matrix = confusion_matrix(all_trues, all_preds, labels=Labels)

# Normalize to percentage (row-wise)
conf_matrix_percent = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Plot 1 — raw counts
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=Labels, yticklabels=Labels, cbar_kws={'label': 'Count'})
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix (Raw Counts)')
plt.show()

# Plot 2 — normalized percentages
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_percent, annot=True, fmt='.3%', cmap='viridis',
            xticklabels=Labels, yticklabels=Labels, cbar_kws={'label': 'Proportion'})
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix (Percentage)')
plt.show()
