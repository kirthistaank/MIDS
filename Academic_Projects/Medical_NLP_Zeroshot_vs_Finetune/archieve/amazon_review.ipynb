# %%
from datasets import load_dataset
from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load dataset

ds = load_dataset("Mouwiya/drug-reviews")

# %%
Data - Scientist - lucky / Amazon_Reviews

# %%
ds.column_names
# Out:
# {'train': ['patient_id',
#   'drugName',
#   'condition',
#   'review',
#   'rating',
#   'date',
#   'usefulCount',
#   'review_length'],
#  'test': ['patient_id',
#   'drugName',
#   'condition',
#   'review',
#   'rating',
#   'date',
#   'usefulCount',
#   'review_length']}

# %%
#ds = load_dataset("Mouwiya/drug-reviews")

# Convert to Pandas for exploration (train split only as example)
df = ds["train"].to_pandas()


# Collapse rating 1–10 → 1–5 buckets
def collapse_rating(r):
    if r in [1, 2]:
        return 1
    elif r in [3, 4]:
        return 2
    elif r in [5, 6]:
        return 3
    elif r in [7, 8]:
        return 4
    elif r in [9, 10]:
        return 5


df["rating_bucket"] = df["rating"].apply(collapse_rating)

# Check distribution (imbalance)
rating_counts = df["rating_bucket"].value_counts().sort_index()
print("Class distribution:\n", rating_counts)

# visualize the distribution
rating_counts.plot(kind="bar", title="Rating Distribution (Collapsed 1–5)")
plt.xlabel("Rating bucket")
plt.ylabel("Count")
plt.show()

#Balance dataset (undersample the majority class for demonstration)
min_count = rating_counts.min()
balanced_df = df.groupby("rating_bucket", group_keys=False).apply(
    lambda x: x.sample(min_count, random_state=42)
)

print("\nBalanced class distribution:\n", balanced_df["rating_bucket"].value_counts())
# Out:
# Class distribution:
#  rating_bucket
# 1     4700
# 2     2043
# 3     2616
# 4     5071
# 5    13273
# Name: count, dtype: int64
# Balanced class distribution:
#  rating_bucket
# 1    2043
# 2    2043
# 3    2043
# 4    2043
# 5    2043
# Name: count, dtype: int64
# /var/folders/gj/bbgjz4_x5ybc58ms5zv9p8sr0000gp/T/ipykernel_67357/2566381247.py:35: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   balanced_df = df.groupby("rating_bucket", group_keys=False).apply(

# %%
balanced_df.head(10)
# Out:
#        patient_id                          drugName                 condition  \
# 25659      181982                     Teriflunomide        multiple sclerosis
# 14313      209748                      Lupron Depot             endometriosis
# 2008       161441                   Diphenhydramine                  insomnia
# 5865        83784  Ethinyl estradiol / norgestimate             birth control
# 8688        71716                          Tramadol                 back pain
# 27526       81572                       Liraglutide               weight loss
# 6743        29134                        Topiramate       migraine prevention
# 17227      152475                     Ciprofloxacin         bladder infection
# 5472       177240                        Duloxetine  major depressive disorde
# 13349      127148                    Metoclopramide           nausea/vomiting
#
#                                                   review  rating  \
# 25659  "I've had MS since I was fifteen, I'm fifty-fo...     1.0
# 14313  "I am on my 2nd shot of Lupron and I am not li...     2.0
# 2008   "I tried using it, took two pills (Recommended...     1.0
# 5865   "I have been on Sprintec for 4 months now, wit...     1.0
# 8688   "Tramadol is just about as useful as Teats on ...     1.0
# 27526  "Been taking Saxenda since 19th May - and so f...     2.0
# 6743   "I started to take topiramate 100mg 6wks ago a...     2.0
# 17227  "I had to stop taken the medicine due to getti...     2.0
# 5472   "I started this drug back in the summer-ish of...     2.0
# 13349  "I was given the medication in tablet form whe...     1.0
#
#                     date  usefulCount  review_length  rating_bucket
# 25659    October 3, 2017            4            100              1
# 14313     March 26, 2009           43             79              1
# 2008       June 10, 2016            8             31              1
# 5865   November 28, 2017            0            128              1
# 8688   February 27, 2017           24             64              1
# 27526      July 30, 2017            8             94              1
# 6743      March 12, 2017           10            109              1
# 17227      March 5, 2011           70             72              1
# 5472      April 13, 2017           11             95              1
# 13349     April 20, 2016            8             71              1

# %%
# save the balanced dataset to you current directory
balanced_df.to_csv("DrugReview_balanced.csv")

# %%
#Revalidate the balanced distribution
# Check distribution (imbalance)
rating_counts = balanced_df["rating_bucket"].value_counts().sort_index()
print("Class distribution:\n", rating_counts)

# visualize
rating_counts.plot(kind="bar", title="Rating Distribution (Collapsed 1–5)")
plt.xlabel("Rating bucket")
plt.ylabel("Count")
plt.show()
# Out:
# Class distribution:
#  rating_bucket
# 1    2043
# 2    2043
# 3    2043
# 4    2043
# 5    2043
# Name: count, dtype: int64

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

text = "This drug really helped with my pain but caused nausea."
candidate_labels = ["very negative", "negative", "neutral", "positive", "very positive"]

result = classifier(text, candidate_labels)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/envs/d266myassignment/lib/python3.9/site-packages/transformers/activations_tf.py in <module>
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/gj/bbgjz4_x5ybc58ms5zv9p8sr0000gp/T/ipykernel_67357/1105183727.py in <cell line: 3>()
#       1 from transformers import pipeline
#       2
# ----> 3 classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
#       4
#       5 text = "This drug really helped with my pain but caused nausea."
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/site-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1026     if isinstance(model, str) or framework is None:
#    1027         model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# -> 1028         framework, model = infer_framework_load_model(
#    1029             adapter_path if adapter_path is not None else model,
#    1030             model_classes=model_classes,
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/site-packages/transformers/pipelines/base.py in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     266                         classes.append(_class)
#     267                 if look_tf:
# --> 268                     _class = getattr(transformers_module, f"TF{architecture}", None)
#     269                     if _class is not None:
#     270                         classes.append(_class)
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/site-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    2300         elif name in self._class_to_module:
#    2301             try:
# -> 2302                 module = self._get_module(self._class_to_module[name])
#    2303                 value = getattr(module, name)
#    2304             except (ModuleNotFoundError, RuntimeError) as e:
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/site-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    2330             return importlib.import_module("." + module_name, self.__name__)
#    2331         except Exception as e:
# -> 2332             raise e
#    2333
#    2334     def __reduce__(self):
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/site-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    2328     def _get_module(self, module_name: str):
#    2329         try:
# -> 2330             return importlib.import_module("." + module_name, self.__name__)
#    2331         except Exception as e:
#    2332             raise e
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/site-packages/transformers/models/bart/modeling_tf_bart.py in <module>
#      22 import tensorflow as tf
#      23
# ---> 24 from ...activations_tf import get_tf_activation
#      25 from ...modeling_tf_outputs import (
#      26     TFBaseModelOutput,
#
# ~/anaconda3/envs/d266myassignment/lib/python3.9/site-packages/transformers/activations_tf.py in <module>
#      25
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
